# %% [markdown]
# <a href="https://colab.research.google.com/github/xanndreas/PCVK_Genap_2021/blob/main/Week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/kitten01.jpg')
plt.imshow(img)

# %%
img2 = img
img3 = cv.cvtColor(img, cv.COLOR_BGR2RGB)
plt.imshow(img3)

# %%
img_gray = cv.imread('/content/kitten01.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap = 'gray')

# %%
plt.imshow(img_gray, cmap='magma')

# %%
img5 = cv.flip(cv.cvtColor(img, cv.COLOR_BGR2RGB),0)
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
ax.imshow(img5)

# %%
black_image = np.zeros(shape=(512,512,3), dtype=np.int16)
plt.imshow(black_image)

# %%
cv.rectangle(black_image, pt1=(384,0), pt2=(510,150), color=(0,255,0), thickness=10)
plt.imshow(black_image)

# %%
cv.rectangle(black_image, pt1=(200,200), pt2=(300,300), color=(0,0,255), thickness=15)
plt.imshow(black_image)

# %%
cv.circle(black_image,center=(100,100), radius=50, color=(255,0,0), thickness=8)
plt.imshow(black_image)

# %%
black_images = black_image
cv.line(black_images,pt1=(0,0), pt2=(512,512), color=(255,255,255), thickness=5)
plt.imshow(black_images)

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_images, text='Hello', org=(10,500), fontFace=font, fontScale=4, 
           color=(255,255,0), thickness=2, lineType=cv.LINE_AA)
plt.imshow(black_images)

# %%
black_img2 = np.zeros(shape=(512,512,3), dtype=np.int32)
plt.imshow(black_img2)

# %%
vertices = np.array([[100,300],[200,200],[400,300],[200,400]], dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
pts = vertices.reshape((-1,1,2))
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
cv.polylines(black_img2, [pts], isClosed=True, color=(255,0,0), thickness=5)
plt.imshow(black_img2)

# %% [markdown]
# **Task**
# 1. Apakah perbedaan gambar yang ditampilkan tanpa dan dengan matplotlib?
# > Dengan matplotlib, terdapat satu atau lebih axes / sumbu saat menampilkan gambar
# 2. Apakah perbedaan dan pengaruhnya pembuatan black image antara tipe data int16
# dan int32?
# >  Setiap kata int32 akan dibangun dari dua kata int16. Jadi hanya akan ada 5 kata kunci int32 seperti pada contoh praktikum
#
#   > Selanjutnya, urutan byte dalam bilangan bulat 32 bit dari 16 bit pertama adalah bit LSB. Jadi, lihat representasi hex dari dua kata pertama. Dalam 16 bit adalah: 0x0000 = 0 dan 0x0001 = 1. Ketika bit yang sama digunakan dalam kata 32 bit, maka akan mendapatkan 0x0001 0000 = 65536 karena urutan bit yang agak tidak intuitif ini.
#
# 3. Jelaskan tentang angka-angka yang terdapat pada reshape((-1,1,2))
# > Memberikan bentuk baru dalam array tanpa mengubah data di dalamnya. Angka tersebut untuk memberikan nilai array yang akan di reshape, shape baru, dan order
# > Untuk menampilkan gambar dalam 1 window
# 4. Apakah kegunaan “google.colab.patches import cv2_imshow” pada potongan kode
# berikut
# > Untuk menampilkan gambar dalam 1 window
# 5. Apakah kegunaan “skimage impot io” pada potongan kode soal nomor 4
# > Untuk menghasilkan gambar  dalam NumPy Arrays dari file gambar

# %%
img5 = cv.flip(cv.cvtColor(img, cv.COLOR_BGR2RGB),0)
fig = plt.figure(figsize=(10,10))
ax=fig.add_subplot(111)
ax.imshow(img5)

# %%
from matplotlib.colors import ListedColormap,LinearSegmentedColormap
img3 = img
top = plt.get_cmap('Reds', 50) # r means reversed version
bottom = plt.get_cmap('Greens', 50)# combine it all
newcolors = np.vstack((top(np.linspace(0, 1, 128)),
                       bottom(np.linspace(0, 1, 128))))
red_greens = ListedColormap(newcolors, name='red_greens')
plt.imshow(img3, red_greens)

# %%
img4 = img
top2 = plt.get_cmap('Greens', 250) # r means reversed version
bottom2 = plt.get_cmap('Blues', 250)# combine it all
newcolors = np.vstack((top2(np.linspace(0, 1, 250)),
                       bottom2(np.linspace(0, 1, 250))))
green_blue = ListedColormap(newcolors, name='green_blue')
plt.imshow(img4, green_blue)

# %%
import cv2 as cv
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
from google.colab.patches import cv2_imshow #imagedisplay

y = 10
x = 10
h = 100
w = 100

img = cv.imread('/content/kitten02.jpg')
crop_img = img[y:y+h, x:x+w]
cv2_imshow(crop_img)
# Out:
# <PIL.Image.Image image mode=RGB size=100x100 at 0x7FB701D607D0>

# %%
import cv2 as cv
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
from google.colab.patches import cv2_imshow #imagedisplay

y = 5
x = 5
h = 50
w = 50

img2 = cv.imread('/content/kitten02.jpg')
crop_img2 = img2[y:y+h, x:x+w]
cv2_imshow(crop_img2)
# Out:
# <PIL.Image.Image image mode=RGB size=50x50 at 0x7FB701D60950>

# %%
from numpy import random 
black_img2=np.zeros(shape=(512,512,3),dtype=np.int32)

for i in range(5):
  a= random.randint(0,512)
  b= random.randint(0,512)
  colour = (random.randint(0,255),random.randint(0,255),random.randint(0,255))
  cv.rectangle(black_img2,pt1=(a,a),pt2=(b,b),color= colour,thickness=5)

plt.imshow(black_img2)

# %%
img5 = cv.flip(cv.cvtColor(img, cv.COLOR_BGR2RGB),0)
plt.imshow(img5)

# %%
mypict = cv.imread('/content/IMG_20200301_020526.jpg')
mypict = cv.cvtColor(mypict, cv.COLOR_BGR2RGB)
cv.rectangle(mypict, pt1=(4000,3000), pt2=(3000,1800), color=(0,0,255), 
             thickness=30)
cv.circle(mypict,center=(3500,2000), radius=500, color=(255,0,0), 
          thickness=15)
plt.imshow(mypict)

# %%
lenna = cv.imread('/content/lenna.png')
blue_channel = lenna[:,:,2]
blue_img = np.zeros(lenna.shape)
blue_img[:,:,2] = blue_channel
cv.imwrite('/content/lenna.png',blue_img) 
cv.rectangle(lenna, pt1=(200,500), pt2=(0,300), color=(255,255,255), 
             thickness=5)
plt.imshow(lenna)

# %%
kucing = cv.imread('/content/kitten02.jpg')
kucing = cv.cvtColor(kucing, cv.COLOR_BGR2RGB)
font = cv.FONT_HERSHEY_PLAIN
cv.putText(kucing, text='KITTEN', org=(100,250), fontFace=font, fontScale=4, 
           color=(255,255,255), thickness=5, lineType=cv.LINE_AA)
plt.imshow(kucing)
